# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import re , urllib , http.cookiejar , base64 , binascii , rsa, json, time

__version__ = '0.0.1'
__author__ = 'Pidong Li (hope-dream@163.com)'
cj = http.cookiejar.LWPCookieJar()
cookie_support = urllib.request.HTTPCookieProcessor(cj)
opener = urllib.request.build_opener(cookie_support , urllib.request.HTTPHandler)
urllib.request.install_opener(opener)

# %%
headers = {"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36"}    
url = 'http://aaa2.nwsuaf.edu.cn:8080/selfservice/'
# url = 'http://www.baidu.com'
# url_img = 'http://aaa2.nwsuaf.edu.cn:8080/selfservice/common/web/verifycode.jsp'

request = urllib.request.Request(url, headers = headers)
response = urllib.request.urlopen(request)
text = response.read()
# with open('code.jpg', 'wb') as f:
#     f.write(text)
print(cj.as_lwp_str())
# Out:
# Set-Cookie3: JSESSIONID=7777752B3B9AA6E3F511741C92D2F547; path="/selfservice"; domain="aaa2.nwsuaf.edu.cn"; path_spec; discard; version=0

# %%
headers = {"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36"}    
url_img = 'http://aaa2.nwsuaf.edu.cn:8080/selfservice/common/web/verifycode.jsp'

request = urllib.request.Request(url_img, headers = headers)
response = urllib.request.urlopen(request)
text = response.read()
with open('code.jpg', 'wb') as f:
    f.write(text)
print(cj)
# Out:
# <LWPCookieJar[<Cookie JSESSIONID=7777752B3B9AA6E3F511741C92D2F547 for aaa2.nwsuaf.edu.cn/selfservice>]>

# %%
# headers需要我们自己来模拟
# verify = input('please input the verify code')
# 
headers = {
"Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
"Accept-Encoding":"gzip, deflate",
"Accept-Language":"zh-CN,zh;q=0.8,en-US;q=0.6,en;q=0.4",
"Cache-Control":"max-age=0",
"Connection":"keep-alive",

"Content-Type":"application/x-www-form-urlencoded",
# "Cookie":"JSESSIONID=0B058354994C1F6BC1A0451E36FDA98F; pgv_pvi=379089920",
"Host":"aaa2.nwsuaf.edu.cn:8080",
"Origin":"http://aaa2.nwsuaf.edu.cn:8080",
"Referer":"http://aaa2.nwsuaf.edu.cn:8080/selfservice/module/scgroup/web/login_self.jsf",
"Upgrade-Insecure-Requests":"1",
"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36"    

}
para = {"act" : "add",
        "name" : "2012015281",
        "password" : "660808",
        "verify" : '4902'}
# 　　这里的urlencode用于把一个请求对象用'&'来接来字符串化，接着就是编码成utf-8
url_post = 'http://aaa2.nwsuaf.edu.cn:8080/selfservice/module/scgroup/web/login_judge.jsf'
data = urllib.parse.urlencode(para).encode('utf-8')
request = urllib.request.Request(url_post , data, headers)
response = urllib.request.urlopen(request)
text = response.read().decode('gbk')
print(cj)
# Out:
# <LWPCookieJar[<Cookie JSESSIONID=7777752B3B9AA6E3F511741C92D2F547 for aaa2.nwsuaf.edu.cn/selfservice>]>

# %%
url_check = 'http://aaa2.nwsuaf.edu.cn:8080/selfservice/module/webcontent/web/content_self.jsf'
# 　　这里的urlencode用于把一个请求对象用'&'来接来字符串化，接着就是编码成utf-8
request_check = urllib.request.Request(url_check, headers = headers)
response_check = urllib.request.urlopen(request_check)
text_check = response_check.read().decode('gbk')
print(cj)
print(text_check)
# Out:
# <LWPCookieJar[<Cookie JSESSIONID=7777752B3B9AA6E3F511741C92D2F547 for aaa2.nwsuaf.edu.cn/selfservice>]>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script language="javascript">
# function killErrors () {return true;}
# window.onerror = killErrors;
# </script>
# <iframe style="display:none;" width="100%" height="0px"  scrolling="no" marginheight="0" marginwidth="0" frameborder="0"></iframe>
#
#
# <html>
#
#
# <head>
# <title>欢迎使用RG-SAM用户自助服务系统</title>
# <link href="/selfservice/common/self/css/mainpage.css" type="text/css" rel="stylesheet">
# <script language="javascript" src="/selfservice/common/self/js/common.js"></script>
#
# <style>
#
# .summarytitle {
# 	text-align: center;
# 	height: 22px;
# 	border:0px solid #355995;
# 	/*border-bottom: 1px solid #355995;
# 			background-image:url(../img/table_bg.gif);*/
# 	font-size: 20px;
# 	font-weight: bold;
# 	color: #000000;
# }
#
#
# .summarycolumn1 {
# 	text-align: right;
# 	width: 150px;
#
# 	/*border: 1px solid #355995;*/
# 	height: 22px;
# ...

# %%
urllib.request.urlretrieve(url_check, 'check.html')
# Out:
# ('check.html', <http.client.HTTPMessage at 0x104fcc748>)

# %%
cj.save('cookie.txt')

# %%
response.c()

# %%
response_check.getheaders()
